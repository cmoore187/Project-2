# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress
from splinter import Browser
from bs4 import BeautifulSoup as bs
import pandas as pd
from webdriver_manager.chrome import ChromeDriverManager

# %%
# Reference the file where the CSV is located
accidental_deaths_csv_path = "Resources/accidental_deaths.csv"

# Import the data into a Pandas DataFrame
accidental_deaths_df = pd.read_csv(accidental_deaths_csv_path)
accidental_deaths_df
# Out:
#       Incident ID  Month  Year         State               City Or County  \
# 0         2022551      6  2021      Illinois                       Joliet
# 1         2022188      6  2021         Texas  Lumberton (Rose Hill Acres)
# 2         2021159      5  2021      Kentucky                     Radcliff
# 3         2022433      5  2021  Pennsylvania                  Coatesville
# 4         2019036      5  2021       Georgia                      Jackson
# ...           ...    ...   ...           ...                          ...
# 1995       784473      2  2017      Colorado                       Pueblo
# 1996       783782      2  2017     Tennessee                      Clifton
# 1997       783373      2  2017       Georgia                    Grovetown
# 1998       787701      2  2017     Minnesota                       Sebeka
# 1999       783455      2  2017     Louisiana                 Lake Charles
#
#                         Address  # Killed  # Injured  Operations
# 0             201 S Eastern Ave         1          0         NaN
# 1                    4940 US 69         1          0         NaN
# 2                           NaN         1          0         NaN
# 3     300 block of Community Ln         1          0         NaN
# 4                     School St         1          1         NaN
# ...                         ...       ...        ...         ...
# 1995        4103 N Elizabeth St         1          0         NaN
# 1996       2373 Culps Bend Road         1          0         NaN
# 1997            Coventry Avenue         1          0         NaN
# 1998                        NaN         1          0         NaN
# 1999      1700 block of Rena St         1          0         NaN
#
# [2000 rows x 9 columns]

# %%
death_counts = accidental_deaths_df.set_index('State')
death_counts
# Out:
#               Incident ID  Month  Year               City Or County  \
# State
# Illinois          2022551      6  2021                       Joliet
# Texas             2022188      6  2021  Lumberton (Rose Hill Acres)
# Kentucky          2021159      5  2021                     Radcliff
# Pennsylvania      2022433      5  2021                  Coatesville
# Georgia           2019036      5  2021                      Jackson
# ...                   ...    ...   ...                          ...
# Colorado           784473      2  2017                       Pueblo
# Tennessee          783782      2  2017                      Clifton
# Georgia            783373      2  2017                    Grovetown
# Minnesota          787701      2  2017                       Sebeka
# Louisiana          783455      2  2017                 Lake Charles
#
#                                 Address  # Killed  # Injured  Operations
# State
# Illinois              201 S Eastern Ave         1          0         NaN
# Texas                        4940 US 69         1          0         NaN
# Kentucky                            NaN         1          0         NaN
# Pennsylvania  300 block of Community Ln         1          0         NaN
# Georgia                       School St         1          1         NaN
# ...                                 ...       ...        ...         ...
# Colorado            4103 N Elizabeth St         1          0         NaN
# Tennessee          2373 Culps Bend Road         1          0         NaN
# Georgia                 Coventry Avenue         1          0         NaN
# Minnesota                           NaN         1          0         NaN
# Louisiana         1700 block of Rena St         1          0         NaN
#
# [2000 rows x 8 columns]

# %%
death_counts_state = death_counts.groupby(['State', 'Year'])
death_counts_state

sum_death = death_counts_state.sum()
sum_death
# Out:
#                 Incident ID  Month  # Killed  # Injured  Operations
# State     Year
# Alabama   2017     12972655    117        14          1         0.0
#           2018     20340358     99        18          4         0.0
#           2019     28551827    120        20          6         0.0
#           2020     32407378    109        19          6         0.0
#           2021      9879222     19         5          5         0.0
# ...                     ...    ...       ...        ...         ...
# Wisconsin 2018      8843073     49         7          0         0.0
#           2019     11734454     61         8          0         0.0
#           2020     13949580     54         8          0         0.0
#           2021      3956994      8         2          0         0.0
# Wyoming   2020      1862872     11         1          0         0.0
#
# [220 rows x 5 columns]

# %%
YearCount = death_counts['Year'].value_counts()
YearCount
# Out:
# 2020    587
# 2019    408
# 2018    399
# 2017    399
# 2021    207
# Name: Year, dtype: int64

# %%
State_counts = accidental_deaths_df['State'].value_counts()
State_counts
# Out:
# Texas                   237
# Florida                 119
# Georgia                 100
# Tennessee                95
# Ohio                     93
# Illinois                 79
# Alabama                  76
# Missouri                 72
# Michigan                 70
# Louisiana                67
# Mississippi              65
# Pennsylvania             65
# Indiana                  62
# California               59
# South Carolina           58
# Virginia                 56
# North Carolina           52
# New York                 51
# Arizona                  46
# Kentucky                 44
# Oklahoma                 37
# Arkansas                 34
# Washington               33
# Wisconsin                31
# Colorado                 28
# Kansas                   25
# Minnesota                25
# Maryland                 22
# Oregon                   18
# Iowa                     18
# West Virginia            17
# Utah                     16
# Nevada                   16
# Nebraska                 13
# New Mexico               13
# Montana                  11
# Idaho                    10
# Alaska                   10
# New Jersey                9
# Connecticut               8
# Maine                     8
# South Dakota              8
# Massachusetts             8
# New Hampshire             4
# North Dakota              3
# District of Columbia      3
# Hawaii                    2
# Wyoming                   1
# Rhode Island              1
# Delaware                  1
# Vermont                   1
# Name: State, dtype: int64

# %%
State_counts.plot(kind='bar', alpha = 0.5, align = "center", color ="red", figsize=(20,3))

plt.xlabel("State")
plt.ylabel("Death")
plt.title("Accidental death by state")

# Save the figure
plt.savefig("Bar Chart of Accidental death by state.png")
plt.show()

# %%
# Reference the file where the CSV is located
accidental_injuries_csv_path = "Resources/accidental_injuries.csv"

# Import the data into a Pandas DataFrame
accidental_injuries_df = pd.read_csv(accidental_injuries_csv_path)
accidental_injuries_df
# Out:
#       Incident ID  Month  Year           State  City Or County  \
# 0         2023222      6  2021         Alabama          Helena
# 1         2023013      6  2021        New York            Troy
# 2         2021772      6  2021           Texas     San Antonio
# 3         2022441      6  2021        Michigan        Highland
# 4         2023091      6  2021     Mississippi          Canton
# ...           ...    ...   ...             ...             ...
# 1995      1617203      2  2020         Alabama       Fairfield
# 1996      1617069      2  2020      California      Long Beach
# 1997      1616548      2  2020        Kentucky        Franklin
# 1998      1616342      2  2020        Maryland  Lexington Park
# 1999      1616211      2  2020  South Carolina      Walterboro
#
#                          Address  # Killed  # Injured  Operations
# 0                    4730 Hwy 17         0          1         NaN
# 1                            NaN         0          1         NaN
# 2                10362 Sahara Dr         0          1         NaN
# 3     2000 block of N Milford Rd         0          1         NaN
# 4                117 S Hargon St         0          1         NaN
# ...                          ...       ...        ...         ...
# 1995        300 block of 67th St         0          1         NaN
# 1996  2500 block of Santa Fe Ave         0          1         NaN
# 1997           1550 Nashville Rd         0          1         NaN
# 1998            21374 Sanners Rd         0          1         NaN
# 1999               656 Bells Hwy         0          1         NaN
#
# [2000 rows x 9 columns]

# %%
# splinter setup
executablepath = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executablepath, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Get LATEST driver version for 91.0.4472
# Trying to download new driver from https://chromedriver.storage.googleapis.com/91.0.4472.19/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\adria\.wdm\drivers\chromedriver\win32\91.0.4472.19]

# %%
#visit the url for the mars news site
url = 'https://www.gunviolencearchive.org/reports'
browser.visit(url)

# Create a beautiful soup object
html = browser.html
news_soup = bs(html, 'html.parser')
